# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
hours_studied = np.linspace(0, 8, 100)

# %%
exam_grades = 2.1 * h ours_studied + 2. + 1.5 * np.random.randn(hours_studied.shape[0])
exam_grades = np.clip(exam_grades, 0, 20)

# %%
prediction_1 = 1.5 * hours_studied + .2
prediction_2 = 2 * hours_studied + .5

# %%
plt.figure(figsize = (15, 8))
plt.scatter(hours_studied, exam_grades)
plt.plot(hours_studied, prediction_1, label = 'Model 1')
plt.plot(hours_studied, prediction_2, label = 'Model 2')
plt.xlabel('Hours studied')
plt.ylabel('Exam grade')
plt.legend()

# %%
error_by_student = (exam_grades - prediction_1) ** 2
error = error_by_student.mean()
error
# Out:
# 21.180977004080567

# %%
error_by_student = (exam_grades - prediction_2) ** 2
error = error_by_student.mean()
error
# Out:
# 5.54569503982808

# %%
prediction_3 = 2 * hours_studied + .6
error_by_student = (exam_grades - prediction_3) ** 2
error = error_by_student.mean()
error
# Out:
# 5.200007526764063

# %%
b_values = np.linspace(0, 4, 50)
b_values
# Out:
# array([0.        , 0.08163265, 0.16326531, 0.24489796, 0.32653061,
#        0.40816327, 0.48979592, 0.57142857, 0.65306122, 0.73469388,
#        0.81632653, 0.89795918, 0.97959184, 1.06122449, 1.14285714,
#        1.2244898 , 1.30612245, 1.3877551 , 1.46938776, 1.55102041,
#        1.63265306, 1.71428571, 1.79591837, 1.87755102, 1.95918367,
#        2.04081633, 2.12244898, 2.20408163, 2.28571429, 2.36734694,
#        2.44897959, 2.53061224, 2.6122449 , 2.69387755, 2.7755102 ,
#        2.85714286, 2.93877551, 3.02040816, 3.10204082, 3.18367347,
#        3.26530612, 3.34693878, 3.42857143, 3.51020408, 3.59183673,
#        3.67346939, 3.75510204, 3.83673469, 3.91836735, 4.        ])

# %%
predictions_b_moving = 2 * hours_studied + b_values[:, None]

# %%
predictions_b_moving.shape
# Out:
# (50, 100)

# %%
plt.plot(
    b_values,     
    ((exam_grades - predictions_b_moving) ** 2).mean(axis = 1)
)
plt.ylabel('loss')
plt.xlabel('parameter b values')
# Out:
# Text(0.5, 0, 'parameter b values')

# %% [markdown]
# # Scikit-learn

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# input data shape = [# samples, # features]

# %%
hours_studied.shape
# Out:
# (100,)

# %%
exam_grades.shape
# Out:
# (100,)

# %%
LinearRegression?
